# %%
import pandas as pd
import pandas as np

# %%
dadosSinapi = pd.read_excel('datasets/sinapi_dados.xls')

# %%
dadosSinapi
# Out:
#                                       PRECOS DE INSUMOS  \
# 0                                                   NaN
# 1                                MES DE COLETA: 02/2022
# 2                           LOCALIDADE: 3420 - CURITIBA
# 3     ENCARGOS SOCIAIS (%) HORISTA  85,67  MENSALIST...
# 4                                                   NaN
# ...                                                 ...
# 5275                                              41096
# 5276                                              41776
# 5277                                              11157
# 5278                                                NaN
# 5279                            TOTAL DE INSUMOS : 5272
#
#                                              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                   NaN        NaN        NaN
# 1                                                   NaN        NaN        NaN
# ...
